# %%
import pandas as pd
import chardet
import os

from IPython.display import display, Markdown
from tqdm import tqdm

# %%
# Set your working folder (same as this notebook)
FOLDER = "."

# Define file groups
TRAIN_FILES = [
    "consol_alteryx_28-10-2025_FY25.csv",
    "consol_fy25fy26_27-10-2025.csv",
    "consol_alteryx_28-10-2025_FY24"
]
TEST_FILE = "consol_alteryx_28-10-2025_FY26.csv"

# %%
# ------------------------------------------------
# 🧠 Helper Functions
# ------------------------------------------------

def detect_encoding(file_path, n_bytes=200000):
    """Detect encoding using chardet."""
    with open(file_path, "rb") as f:
        result = chardet.detect(f.read(n_bytes))
    display(Markdown(f"**Detected encoding for `{os.path.basename(file_path)}` → `{result['encoding']}` (confidence: {result['confidence']:.2f})**"))
    return result["encoding"]

def find_separator(file_path, encoding):
    # Your files use '±' (U+00B1) as the delimiter
    sep = "±"
    temp = pd.read_csv(file_path, encoding=encoding, sep=sep, nrows=5, engine="python")
    display(Markdown(f"✅ Using separator **`{sep}` (±)** — detected **{temp.shape[1]} columns**"))
    return sep

def load_large_csv(file_path, encoding, sep, chunksize=100000):
    """Read large CSV safely using chunks."""
    chunks = []
    total_rows = 0
    for chunk in tqdm(pd.read_csv(file_path, encoding=encoding, sep=sep, chunksize=chunksize, engine="python"),
                      desc=f"Loading {os.path.basename(file_path)}"):
        chunks.append(chunk)
        total_rows += len(chunk)
    df = pd.concat(chunks, ignore_index=True)
    display(Markdown(f"✅ Loaded `{os.path.basename(file_path)}` → shape: **{df.shape}**"))
    return df

def show_data_summary(df, name="DataFrame"):
    """Display shape, sample, info, missing %, and numeric stats."""
    display(Markdown(f"### 📊 {name} Overview"))
    display(df.head(3))
    display(Markdown(f"**Shape:** {df.shape[0]:,} rows × {df.shape[1]:,} columns"))
    display(Markdown("#### 🔍 Data Info"))
    display(df.info(verbose=False))
    display(Markdown("#### 🧮 Missing Values (%)"))
    display((df.isnull().mean() * 100).round(2).sort_values(ascending=False).head(10))
    display(Markdown("#### 📈 Numeric Columns Summary"))
    display(df.describe(include='number').T.head(10))

# %%
file_path = "consol_alteryx_28-10-2025_FY25.csv"

with open(file_path, "rb") as f:
    raw = f.read(500)
print(raw[:200])
# Out:
# b'Year\xb1Engagement ID\xb1Eng ID\xb1MS\xb1Location\xb1Engagement\xb1Release Date\xb1Last Invoice Issued Date\xb1Last Time Charged Date\xb1Last Expenses Charged Date\xb1Opportunity ID\xb1Opportunity\xb1Opportunity Partner ID\xb1Opportunity P'

# %%
train_dfs = []

for file in TRAIN_FILES:
    path = os.path.join(FOLDER, file)
    enc = "mac_roman"
    sep = "±"
    df = load_large_csv(path, enc, sep)
    train_dfs.append(df)

train_df = pd.concat(train_dfs, ignore_index=True)
show_data_summary(train_df, "TRAIN DATA (Merged)")
# Out:
# Loading consol_alteryx_28-10-2025_FY25.csv: 0it [00:00, ?it/s]
# Loading consol_alteryx_28-10-2025_FY25.csv: 11it [02:12, 12.01s/it]
# ✅ Loaded `consol_alteryx_28-10-2025_FY25.csv` → shape: **(1062745, 170)**
# Loading consol_fy25fy26_27-10-2025.csv: 14it [02:35, 11.07s/it]
# ✅ Loaded `consol_fy25fy26_27-10-2025.csv` → shape: **(1363637, 134)**
# ### 📊 TRAIN DATA (Merged) Overview
#    Year Engagement ID      Eng ID   MS Location  \
# 0  FY25    E-67195917  67195917.0  NaN      NaN
# 1  FY25    E-67407732  67407732.0  NaN      NaN
# 2  FY25    E-45286932  45286932.0  NaN      NaN
#
#                              Engagement         Release Date  \
# 0  AB173-Signify Stat Audit YE Dec 2022  2023-02-23 00:00:00
# 1          CB104 AWSBPL Stat Audit FY23  2023-05-03 00:00:00
# 2        SC TIC Mfg+Ind Group Report 22  2023-01-04 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-09-15 00:00:00    2024-07-07 00:00:00        2024-07-01 00:00:00
# 1      2024-02-21 00:00:00    2024-04-23 00:00:00        2024-07-04 00:00:00
# 2      2022-08-23 00:00:00    2022-10-21 00:00:00        2023-12-06 00:00:00
#
#    ... Location Partner                                       source_file  \
# 0  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 1  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 2  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
#
#    Year1 Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 0   FY25         FY25         FY25            01JUL     2
# 1   FY25         FY25         FY25            01JUL     2
# 2   FY25         FY25         FY25            01JUL     2
#
#                File_Name Same FY? Month
# 0  Engagement List_Wk 02        Y   JUL
# 1  Engagement List_Wk 02        Y   JUL
# 2  Engagement List_Wk 02        Y   JUL
#
# [3 rows x 170 columns]
# **Shape:** 2,426,382 rows × 170 columns
# #### 🔍 Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426382 entries, 0 to 2426381
# Columns: 170 entries, Year to Month
# dtypes: float64(105), int64(1), object(64)
# memory usage: 3.1+ GB
# None
# #### 🧮 Missing Values (%)
# MS Tagging                  100.00
# Assurance Plan               99.91
# Prorata Plan                 99.91
# Plan                         99.91
# Assurance PY Actual          99.91
# Partner SSL                  99.06
# Partner MS                   99.06
# Audit Partner's Location     97.14
# Audit Partner's MS           97.11
# Audit Partner's GPN          90.80
# dtype: float64
# #### 📈 Numeric Columns Summary
#                               count          mean           std         min  \
# Eng ID                    2417319.0  6.101856e+07  1.059471e+07  12345678.0
# Opportunity Partner ID    2407173.0  3.732495e+07  1.645611e+07   1022886.0
# Engagement Partner GUI    2417251.0  3.843853e+07  1.545715e+07   1007165.0
# Engagement Manager GUI    2417251.0  2.033869e+07  2.127735e+07   1070696.0
# GFIS CID                  2379147.0  1.997944e+07  2.866421e+07         0.0
# Engagement Service Code   2417237.0  1.014040e+04  1.499018e+02     10001.0
# Transaction Service Code  2417237.0  1.014040e+04  1.499018e+02     10001.0
# Charged Hours ETD         2417251.0  1.007250e+03  2.889845e+03     -1394.0
# Charged Hours FYTD        2417251.0  1.788745e+02  1.088892e+03     -3168.0
# Charged Hours MTD         2417237.0  1.964324e+01  1.563148e+02    -10043.0
#
#                                  25%         50%         75%         max
# Eng ID                    45511912.0  67653538.0  68291296.0  69439800.0
# Opportunity Partner ID    45000295.0  45001385.0  45004492.0  51001082.0
# Engagement Partner GUI    45000295.0  45001425.0  45005290.0  45817253.0
# Engagement Manager GUI     2184112.0   3106296.0  45802904.0  45817567.0
# GFIS CID                         0.0         0.0  60703416.0  61892939.0
# Engagement Service Code      10067.0     10067.0     10119.0     11359.0
# Transaction Service Code     10067.0     10067.0     10119.0     11359.0
# Charged Hours ETD               79.0       314.0       926.0    202701.1
# Charged Hours FYTD               0.0         0.0        24.0    103014.0
# Charged Hours MTD                0.0         0.0         0.0     21579.5

# %%
train_df.head
# Out:
# <bound method NDFrame.head of          Year Engagement ID      Eng ID   MS   Location  \
# 0        FY25    E-67195917  67195917.0  NaN        NaN
# 1        FY25    E-67407732  67407732.0  NaN        NaN
# 2        FY25    E-45286932  45286932.0  NaN        NaN
# 3        FY25    E-45146567  45146567.0  NaN        NaN
# 4        FY25    E-42655917  42655917.0  NaN        NaN
# ...       ...           ...         ...  ...        ...
# 2426377  FY26            57         NaN  TMT  Bangalore
# 2426378  FY26            58         NaN  TMT    Chennai
# 2426379  FY26            59         NaN  TMT      Delhi
# 2426380  FY26            60         NaN  TMT  Hyderabad
# 2426381  FY26            61         NaN  TMT     Mumbai
#
#                                    Engagement         Release Date  \
# 0        AB173-Signify Stat Audit YE Dec 2022  2023-02-23 00:00:00
# 1                CB104 AWSBPL Stat Audit FY23  2023-05-03 00:00:00
# 2              SC TIC Mfg+Ind Group Report 22  2023-01-04 00:00:00
# 3              SBL Certification Service 2021  2023-01-04 00:00:00
# 4                        CB171-Project Marine  2023-01-04 00:00:00
# ...                                       ...                  ...
# 2426377                                   NaN                  NaN
# 2426378                                   NaN                  NaN
# 2426379                                   NaN                  NaN
# 2426380                                   NaN                  NaN
# 2426381                                   NaN                  NaN
#
#         Last Invoice Issued Date Last Time Charged Date  \
# 0            2023-09-15 00:00:00    2024-07-07 00:00:00
# 1            2024-02-21 00:00:00    2024-04-23 00:00:00
# 2            2022-08-23 00:00:00    2022-10-21 00:00:00
# 3            2022-04-19 00:00:00    2022-12-02 00:00:00
# 4            2023-09-19 00:00:00                    NaN
# ...                          ...                    ...
# 2426377                      NaN                    NaN
# 2426378                      NaN                    NaN
# 2426379                      NaN                    NaN
# 2426380                      NaN                    NaN
# 2426381                      NaN                    NaN
#
#         Last Expenses Charged Date  ... Location Partner  \
# 0              2024-07-01 00:00:00  ...              NaN
# 1              2024-07-04 00:00:00  ...              NaN
# 2              2023-12-06 00:00:00  ...              NaN
# 3                              NaN  ...              NaN
# 4              2023-04-24 00:00:00  ...              NaN
# ...                            ...  ...              ...
# 2426377                        NaN  ...              NaN
# 2426378                        NaN  ...              NaN
# 2426379                        NaN  ...              NaN
# 2426380                        NaN  ...              NaN
# 2426381                        NaN  ...              NaN
#
#                                                source_file  Year1  \
# 0         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 1         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 2         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 3         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 4         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# ...                                                    ...    ...
# 2426377  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426378  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426379  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426380  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426381  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
#
#         Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 0               FY25         FY25            01JUL     2
# 1               FY25         FY25            01JUL     2
# 2               FY25         FY25            01JUL     2
# 3               FY25         FY25            01JUL     2
# 4               FY25         FY25            01JUL     2
# ...              ...          ...              ...   ...
# 2426377         FY26         FY26            03SEP    13
# 2426378         FY26         FY26            03SEP    13
# 2426379         FY26         FY26            03SEP    13
# 2426380         FY26         FY26            03SEP    13
# 2426381         FY26         FY26            03SEP    13
#
#                             File_Name Same FY? Month
# 0               Engagement List_Wk 02        Y   JUL
# 1               Engagement List_Wk 02        Y   JUL
# 2               Engagement List_Wk 02        Y   JUL
# 3               Engagement List_Wk 02        Y   JUL
# 4               Engagement List_Wk 02        Y   JUL
# ...                               ...      ...   ...
# 2426377  Engagement List_Pivot Wk13 1        Y   SEP
# 2426378  Engagement List_Pivot Wk13 1        Y   SEP
# 2426379  Engagement List_Pivot Wk13 1        Y   SEP
# 2426380  Engagement List_Pivot Wk13 1        Y   SEP
# 2426381  Engagement List_Pivot Wk13 1        Y   SEP
#
# [2426382 rows x 170 columns]>

# %%
# 🔍 Check head and tail for the merged FY25 training data
print("=== TRAIN DATA (FY25) — HEAD ===")
display(train_df.head(5))

print("\n=== TRAIN DATA (FY25) — TAIL ===")
display(train_df.tail(5))
# Out:
# === TRAIN DATA (FY25) — HEAD ===
#    Year Engagement ID      Eng ID   MS Location  \
# 0  FY25    E-67195917  67195917.0  NaN      NaN
# 1  FY25    E-67407732  67407732.0  NaN      NaN
# 2  FY25    E-45286932  45286932.0  NaN      NaN
# 3  FY25    E-45146567  45146567.0  NaN      NaN
# 4  FY25    E-42655917  42655917.0  NaN      NaN
#
#                              Engagement         Release Date  \
# 0  AB173-Signify Stat Audit YE Dec 2022  2023-02-23 00:00:00
# 1          CB104 AWSBPL Stat Audit FY23  2023-05-03 00:00:00
# 2        SC TIC Mfg+Ind Group Report 22  2023-01-04 00:00:00
# 3        SBL Certification Service 2021  2023-01-04 00:00:00
# 4                  CB171-Project Marine  2023-01-04 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-09-15 00:00:00    2024-07-07 00:00:00        2024-07-01 00:00:00
# 1      2024-02-21 00:00:00    2024-04-23 00:00:00        2024-07-04 00:00:00
# 2      2022-08-23 00:00:00    2022-10-21 00:00:00        2023-12-06 00:00:00
# 3      2022-04-19 00:00:00    2022-12-02 00:00:00                        NaN
# 4      2023-09-19 00:00:00                    NaN        2023-04-24 00:00:00
#
#    ... Location Partner                                       source_file  \
# 0  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 1  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 2  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 3  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 4  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
#
#    Year1 Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 0   FY25         FY25         FY25            01JUL     2
# 1   FY25         FY25         FY25            01JUL     2
# 2   FY25         FY25         FY25            01JUL     2
# 3   FY25         FY25         FY25            01JUL     2
# 4   FY25         FY25         FY25            01JUL     2
#
#                File_Name Same FY? Month
# 0  Engagement List_Wk 02        Y   JUL
# 1  Engagement List_Wk 02        Y   JUL
# 2  Engagement List_Wk 02        Y   JUL
# 3  Engagement List_Wk 02        Y   JUL
# 4  Engagement List_Wk 02        Y   JUL
#
# [5 rows x 170 columns]
# === TRAIN DATA (FY25) — TAIL ===
#          Year Engagement ID  Eng ID   MS   Location Engagement Release Date  \
# 2426377  FY26            57     NaN  TMT  Bangalore        NaN          NaN
# 2426378  FY26            58     NaN  TMT    Chennai        NaN          NaN
# 2426379  FY26            59     NaN  TMT      Delhi        NaN          NaN
# 2426380  FY26            60     NaN  TMT  Hyderabad        NaN          NaN
# 2426381  FY26            61     NaN  TMT     Mumbai        NaN          NaN
#
#         Last Invoice Issued Date Last Time Charged Date  \
# 2426377                      NaN                    NaN
# 2426378                      NaN                    NaN
# 2426379                      NaN                    NaN
# 2426380                      NaN                    NaN
# 2426381                      NaN                    NaN
#
#         Last Expenses Charged Date  ... Location Partner  \
# 2426377                        NaN  ...              NaN
# 2426378                        NaN  ...              NaN
# 2426379                        NaN  ...              NaN
# 2426380                        NaN  ...              NaN
# 2426381                        NaN  ...              NaN
#
#                                                source_file  Year1  \
# 2426377  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426378  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426379  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426380  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426381  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
#
#         Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 2426377         FY26         FY26            03SEP    13
# 2426378         FY26         FY26            03SEP    13
# 2426379         FY26         FY26            03SEP    13
# 2426380         FY26         FY26            03SEP    13
# 2426381         FY26         FY26            03SEP    13
#
#                             File_Name Same FY? Month
# 2426377  Engagement List_Pivot Wk13 1        Y   SEP
# 2426378  Engagement List_Pivot Wk13 1        Y   SEP
# 2426379  Engagement List_Pivot Wk13 1        Y   SEP
# 2426380  Engagement List_Pivot Wk13 1        Y   SEP
# 2426381  Engagement List_Pivot Wk13 1        Y   SEP
#
# [5 rows x 170 columns]

# %%
# Load FY26 Test Data
test_path = os.path.join(FOLDER, TEST_FILE)
enc = "mac_roman"
sep = "±"

test_df = load_large_csv(test_path, enc, sep)
show_data_summary(test_df, "TEST DATA (FY26)")
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x0000024F3D20D120>
# Traceback (most recent call last):
#   File "c:\Users\FV586VH\Downloads\VSC\Model\.venv\Lib\site-packages\tqdm\std.py", line 1148, in __del__
#     self.close()
#   File "c:\Users\FV586VH\Downloads\VSC\Model\.venv\Lib\site-packages\tqdm\notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# Loading consol_alteryx_28-10-2025_FY26.csv: 3it [00:28,  9.49s/it]
# ✅ Loaded `consol_alteryx_28-10-2025_FY26.csv` → shape: **(278942, 188)**
# ### 📊 TEST DATA (FY26) Overview
#    Year Engagement ID      Eng ID        MS    Location  \
# 0  FY26    E-67313430  67313430.0  National  Bangladesh
# 1  FY26    E-45403927  45403927.0  National  Bangladesh
# 2  FY26    E-68182933  68182933.0  National  Bangladesh
#
#                              Engagement         Release Date  \
# 0  CB171 - BD Lease Accelerator Support  2023-04-03 00:00:00
# 1        SEBL Stat Audit YE 30 Sep 2022  2023-01-04 00:00:00
# 2         CB178-Siemens Healthcare Ltd.  2024-04-02 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-07-12 00:00:00    2023-05-19 00:00:00                        NaN
# 1      2023-04-06 00:00:00    2023-06-06 00:00:00        2023-12-06 00:00:00
# 2                      NaN                    NaN                        NaN
#
#    ... System ANSR / Tech Revenue FYTD  \
# 0  ...                             NaN
# 1  ...                             NaN
# 2  ...                             NaN
#
#                                          source_file  Year1 Sub_Folder_1  \
# 0  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 1  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 2  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
#
#   Sub_Folder_2 Month_Serialized  Week                    File_Name Same FY?  \
# 0         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 1         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 2         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
#
#   Month
# 0   JUL
# 1   JUL
# 2   JUL
#
# [3 rows x 188 columns]
# **Shape:** 278,942 rows × 188 columns
# #### 🔍 Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278942 entries, 0 to 278941
# Columns: 188 entries, Year to Month
# dtypes: float64(121), int64(1), object(66)
# memory usage: 400.1+ MB
# None
# #### 🧮 Missing Values (%)
# Partner SSL                 100.00
# Assurance PY Actual         100.00
# Assurance Plan              100.00
# Partner MS                  100.00
# MS Tagging                  100.00
# Plan                         99.83
# Prorata Plan                 99.83
# PY closing NUI               98.22
# Audit Partner's Location     95.39
# Audit Partner's MS           95.35
# dtype: float64
# #### 📈 Numeric Columns Summary
#                              count          mean           std         min  \
# Eng ID                    278357.0  6.245104e+07  1.006641e+07  32310157.0
# Opportunity Partner ID    268273.0  3.739433e+07  1.639536e+07   1029616.0
# Engagement Partner GUI    278337.0  3.845100e+07  1.546742e+07   1048075.0
# Engagement Manager GUI    278337.0  1.938691e+07  2.108393e+07   1070696.0
# GFIS CID                  278337.0  1.043667e+05  2.524317e+06         0.0
# Engagement Service Code   278337.0  1.014555e+04  1.540368e+02     10006.0
# Transaction Service Code  278337.0  1.014555e+04  1.540368e+02     10006.0
# Charged Hours ETD         278337.0  1.026791e+03  2.958191e+03         0.0
# Charged Hours FYTD        278337.0  4.792680e+01  3.388500e+02     -1428.0
# Charged Hours MTD         278337.0  1.772806e+01  1.470084e+02     -2492.0
#
#                                  25%         50%         75%         max
# Eng ID                    45546372.0  67897392.0  68635063.0  69439800.0
# Opportunity Partner ID    45000295.0  45001386.0  45004758.0  51001082.0
# Engagement Partner GUI    45000295.0  45001482.0  45006265.0  45817253.0
# Engagement Manager GUI     2184112.0   3062902.0  45802426.0  45817567.0
# GFIS CID                         0.0         0.0         0.0  61878441.0
# Engagement Service Code      10067.0     10067.0     10119.0     11359.0
# Transaction Service Code     10067.0     10067.0     10119.0     11359.0
# Charged Hours ETD               86.0       330.0       943.8    120462.3
# Charged Hours FYTD               0.0         0.0         0.0     31235.5
# Charged Hours MTD                0.0         0.0         0.0     12829.0

# %%
# 🔍 Check head and tail for FY26 test data
print("=== TEST DATA (FY26) — HEAD ===")
display(test_df.head(5))

print("\n=== TEST DATA (FY26) — TAIL ===")
display(test_df.tail(5))
# Out:
# === TEST DATA (FY26) — HEAD ===
#    Year Engagement ID      Eng ID        MS    Location  \
# 0  FY26    E-67313430  67313430.0  National  Bangladesh
# 1  FY26    E-45403927  45403927.0  National  Bangladesh
# 2  FY26    E-68182933  68182933.0  National  Bangladesh
# 3  FY26    E-68506663  68506663.0  National  Bangladesh
# 4  FY26    E-45003752  45003752.0  National  Bangladesh
#
#                              Engagement         Release Date  \
# 0  CB171 - BD Lease Accelerator Support  2023-04-03 00:00:00
# 1        SEBL Stat Audit YE 30 Sep 2022  2023-01-04 00:00:00
# 2         CB178-Siemens Healthcare Ltd.  2024-04-02 00:00:00
# 3      CB138-SCCBD Stat Audit 31 Dec 24  2024-08-05 00:00:00
# 4                JBL Stat Audit FY 2021  2023-01-04 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-07-12 00:00:00    2023-05-19 00:00:00                        NaN
# 1      2023-04-06 00:00:00    2023-06-06 00:00:00        2023-12-06 00:00:00
# 2                      NaN                    NaN                        NaN
# 3                      NaN    2025-06-02 00:00:00        2025-01-23 00:00:00
# 4      2023-03-01 00:00:00    2023-06-06 00:00:00        2023-10-17 00:00:00
#
#    ... System ANSR / Tech Revenue FYTD  \
# 0  ...                             NaN
# 1  ...                             NaN
# 2  ...                             NaN
# 3  ...                             NaN
# 4  ...                             NaN
#
#                                          source_file  Year1 Sub_Folder_1  \
# 0  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 1  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 2  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 3  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 4  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
#
#   Sub_Folder_2 Month_Serialized  Week                    File_Name Same FY?  \
# 0         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 1         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 2         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 3         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 4         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
#
#   Month
# 0   JUL
# 1   JUL
# 2   JUL
# 3   JUL
# 4   JUL
#
# [5 rows x 188 columns]
# === TEST DATA (FY26) — TAIL ===
#         Year Engagement ID  Eng ID   MS   Location Engagement Release Date  \
# 278937  FY26            57     NaN  TMT  Bangalore        NaN          NaN
# 278938  FY26            58     NaN  TMT    Chennai        NaN          NaN
# 278939  FY26            59     NaN  TMT      Delhi        NaN          NaN
# 278940  FY26            60     NaN  TMT  Hyderabad        NaN          NaN
# 278941  FY26            61     NaN  TMT     Mumbai        NaN          NaN
#
#        Last Invoice Issued Date Last Time Charged Date  \
# 278937                      NaN                    NaN
# 278938                      NaN                    NaN
# 278939                      NaN                    NaN
# 278940                      NaN                    NaN
# 278941                      NaN                    NaN
#
#        Last Expenses Charged Date  ... System ANSR / Tech Revenue FYTD  \
# 278937                        NaN  ...                             NaN
# 278938                        NaN  ...                             NaN
# 278939                        NaN  ...                             NaN
# 278940                        NaN  ...                             NaN
# 278941                        NaN  ...                             NaN
#
#                                               source_file  Year1 Sub_Folder_1  \
# 278937  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26         FY26
# 278938  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26         FY26
# 278939  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26         FY26
# 278940  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26         FY26
# 278941  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26         FY26
#
#        Sub_Folder_2 Month_Serialized  Week                     File_Name  \
# 278937         FY26            03SEP    13  Engagement List_Pivot Wk13 1
# 278938         FY26            03SEP    13  Engagement List_Pivot Wk13 1
# 278939         FY26            03SEP    13  Engagement List_Pivot Wk13 1
# 278940         FY26            03SEP    13  Engagement List_Pivot Wk13 1
# 278941         FY26            03SEP    13  Engagement List_Pivot Wk13 1
#
#        Same FY? Month
# 278937        Y   SEP
# 278938        Y   SEP
# 278939        Y   SEP
# 278940        Y   SEP
# 278941        Y   SEP
#
# [5 rows x 188 columns]

# %%
# Check how many rows belong to each Fiscal Year
fy_counts = train_df["Year"].value_counts(dropna=False)
display(Markdown("### 📊 Fiscal Year Distribution in TRAIN Data"))
display(fy_counts)
# Out:
# ### 📊 Fiscal Year Distribution in TRAIN Data
# Year
# FY25    2147440
# FY26     278942
# Name: count, dtype: int64

# %%
# ------------------------------------------------
# 🧮 Separate FY25 & FY26 from merged training data
# ------------------------------------------------

# FY25 data (for training)
train_df_fy25 = train_df[train_df["Year"] == "FY25"].copy()

# FY26 data found in training file (leak)
fy26_from_train = train_df[train_df["Year"] == "FY26"].copy()

print(f"FY25 rows (train): {len(train_df_fy25):,}")
print(f"FY26 rows (from training): {len(fy26_from_train):,}")
# Out:
# FY25 rows (train): 2,147,440
# FY26 rows (from training): 278,942

# %%
fy26_from_train.describe
# Out:
# <bound method NDFrame.describe of          Year Engagement ID      Eng ID        MS    Location  \
# 2147440  FY26    E-67313430  67313430.0  National  Bangladesh
# 2147441  FY26    E-45403927  45403927.0  National  Bangladesh
# 2147442  FY26    E-68182933  68182933.0  National  Bangladesh
# 2147443  FY26    E-68506663  68506663.0  National  Bangladesh
# 2147444  FY26    E-45003752  45003752.0  National  Bangladesh
# ...       ...           ...         ...       ...         ...
# 2426377  FY26            57         NaN       TMT   Bangalore
# 2426378  FY26            58         NaN       TMT     Chennai
# 2426379  FY26            59         NaN       TMT       Delhi
# 2426380  FY26            60         NaN       TMT   Hyderabad
# 2426381  FY26            61         NaN       TMT      Mumbai
#
#                                    Engagement         Release Date  \
# 2147440  CB171 - BD Lease Accelerator Support  2023-04-03 00:00:00
# 2147441        SEBL Stat Audit YE 30 Sep 2022  2023-01-04 00:00:00
# 2147442         CB178-Siemens Healthcare Ltd.  2024-04-02 00:00:00
# 2147443      CB138-SCCBD Stat Audit 31 Dec 24  2024-08-05 00:00:00
# 2147444                JBL Stat Audit FY 2021  2023-01-04 00:00:00
# ...                                       ...                  ...
# 2426377                                   NaN                  NaN
# 2426378                                   NaN                  NaN
# 2426379                                   NaN                  NaN
# 2426380                                   NaN                  NaN
# 2426381                                   NaN                  NaN
#
#         Last Invoice Issued Date Last Time Charged Date  \
# 2147440      2023-07-12 00:00:00    2023-05-19 00:00:00
# 2147441      2023-04-06 00:00:00    2023-06-06 00:00:00
# 2147442                      NaN                    NaN
# 2147443                      NaN    2025-06-02 00:00:00
# 2147444      2023-03-01 00:00:00    2023-06-06 00:00:00
# ...                          ...                    ...
# 2426377                      NaN                    NaN
# 2426378                      NaN                    NaN
# 2426379                      NaN                    NaN
# 2426380                      NaN                    NaN
# 2426381                      NaN                    NaN
#
#         Last Expenses Charged Date  ... Location Partner  \
# 2147440                        NaN  ...              NaN
# 2147441        2023-12-06 00:00:00  ...              NaN
# 2147442                        NaN  ...              NaN
# 2147443        2025-01-23 00:00:00  ...              NaN
# 2147444        2023-10-17 00:00:00  ...              NaN
# ...                            ...  ...              ...
# 2426377                        NaN  ...              NaN
# 2426378                        NaN  ...              NaN
# 2426379                        NaN  ...              NaN
# 2426380                        NaN  ...              NaN
# 2426381                        NaN  ...              NaN
#
#                                                source_file  Year1  \
# 2147440  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26
# 2147441  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26
# 2147442  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26
# 2147443  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26
# 2147444  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26
# ...                                                    ...    ...
# 2426377  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426378  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426379  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426380  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
# 2426381  FY26__FY26__03.Sep__Wk13__Engagement List_Pivo...   FY26
#
#         Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 2147440         FY26         FY26            01JUL     3
# 2147441         FY26         FY26            01JUL     3
# 2147442         FY26         FY26            01JUL     3
# 2147443         FY26         FY26            01JUL     3
# 2147444         FY26         FY26            01JUL     3
# ...              ...          ...              ...   ...
# 2426377         FY26         FY26            03SEP    13
# 2426378         FY26         FY26            03SEP    13
# 2426379         FY26         FY26            03SEP    13
# 2426380         FY26         FY26            03SEP    13
# 2426381         FY26         FY26            03SEP    13
#
#                             File_Name Same FY? Month
# 2147440   FY25_EngagementList_Wk03 BI        Y   JUL
# 2147441   FY25_EngagementList_Wk03 BI        Y   JUL
# 2147442   FY25_EngagementList_Wk03 BI        Y   JUL
# 2147443   FY25_EngagementList_Wk03 BI        Y   JUL
# 2147444   FY25_EngagementList_Wk03 BI        Y   JUL
# ...                               ...      ...   ...
# 2426377  Engagement List_Pivot Wk13 1        Y   SEP
# 2426378  Engagement List_Pivot Wk13 1        Y   SEP
# 2426379  Engagement List_Pivot Wk13 1        Y   SEP
# 2426380  Engagement List_Pivot Wk13 1        Y   SEP
# 2426381  Engagement List_Pivot Wk13 1        Y   SEP
#
# [278942 rows x 170 columns]>

# %%
train_df_fy25.describe
# Out:
# <bound method NDFrame.describe of          Year Engagement ID      Eng ID        MS   Location  \
# 0        FY25    E-67195917  67195917.0       NaN        NaN
# 1        FY25    E-67407732  67407732.0       NaN        NaN
# 2        FY25    E-45286932  45286932.0       NaN        NaN
# 3        FY25    E-45146567  45146567.0       NaN        NaN
# 4        FY25    E-42655917  42655917.0       NaN        NaN
# ...       ...           ...         ...       ...        ...
# 2147435  FY25           NaN         NaN       IIC       Pune
# 2147436  FY25           NaN         NaN       IIC  Ahmedabad
# 2147437  FY25           NaN         NaN       IIC      Delhi
# 2147438  FY25           NaN         NaN       IIC       East
# 2147439  FY25           NaN         NaN  National     Mumbai
#
#                                    Engagement         Release Date  \
# 0        AB173-Signify Stat Audit YE Dec 2022  2023-02-23 00:00:00
# 1                CB104 AWSBPL Stat Audit FY23  2023-05-03 00:00:00
# 2              SC TIC Mfg+Ind Group Report 22  2023-01-04 00:00:00
# 3              SBL Certification Service 2021  2023-01-04 00:00:00
# 4                        CB171-Project Marine  2023-01-04 00:00:00
# ...                                       ...                  ...
# 2147435                                   NaN                  NaN
# 2147436                                   NaN                  NaN
# 2147437                                   NaN                  NaN
# 2147438                                   NaN                  NaN
# 2147439                                   NaN                  NaN
#
#         Last Invoice Issued Date Last Time Charged Date  \
# 0            2023-09-15 00:00:00    2024-07-07 00:00:00
# 1            2024-02-21 00:00:00    2024-04-23 00:00:00
# 2            2022-08-23 00:00:00    2022-10-21 00:00:00
# 3            2022-04-19 00:00:00    2022-12-02 00:00:00
# 4            2023-09-19 00:00:00                    NaN
# ...                          ...                    ...
# 2147435                      NaN                    NaN
# 2147436                      NaN                    NaN
# 2147437                      NaN                    NaN
# 2147438                      NaN                    NaN
# 2147439                      NaN                    NaN
#
#         Last Expenses Charged Date  ... Location Partner  \
# 0              2024-07-01 00:00:00  ...              NaN
# 1              2024-07-04 00:00:00  ...              NaN
# 2              2023-12-06 00:00:00  ...              NaN
# 3                              NaN  ...              NaN
# 4              2023-04-24 00:00:00  ...              NaN
# ...                            ...  ...              ...
# 2147435                        NaN  ...              NaN
# 2147436                        NaN  ...              NaN
# 2147437                        NaN  ...              NaN
# 2147438                        NaN  ...              NaN
# 2147439                        NaN  ...              NaN
#
#                                                source_file  Year1  \
# 0         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 1         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 2         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 3         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# 4         FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02   FY25
# ...                                                    ...    ...
# 2147435  FY25__FY25__12.Jun__Wk 52(Final)__FY25_Engagem...   FY25
# 2147436  FY25__FY25__12.Jun__Wk 52(Final)__FY25_Engagem...   FY25
# 2147437  FY25__FY25__12.Jun__Wk 52(Final)__FY25_Engagem...   FY25
# 2147438  FY25__FY25__12.Jun__Wk 52(Final)__FY25_Engagem...   FY25
# 2147439  FY25__FY25__12.Jun__Wk 52(Final)__FY25_Engagem...   FY25
#
#         Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 0               FY25         FY25            01JUL     2
# 1               FY25         FY25            01JUL     2
# 2               FY25         FY25            01JUL     2
# 3               FY25         FY25            01JUL     2
# 4               FY25         FY25            01JUL     2
# ...              ...          ...              ...   ...
# 2147435         FY25         FY25            12JUN    52
# 2147436         FY25         FY25            12JUN    52
# 2147437         FY25         FY25            12JUN    52
# 2147438         FY25         FY25            12JUN    52
# 2147439         FY25         FY25            12JUN    52
#
#                                         File_Name Same FY? Month
# 0                           Engagement List_Wk 02        Y   JUL
# 1                           Engagement List_Wk 02        Y   JUL
# 2                           Engagement List_Wk 02        Y   JUL
# 3                           Engagement List_Wk 02        Y   JUL
# 4                           Engagement List_Wk 02        Y   JUL
# ...                                           ...      ...   ...
# 2147435  FY25_Engagement List_Power BI_Pivot Wk52        Y   JUN
# 2147436  FY25_Engagement List_Power BI_Pivot Wk52        Y   JUN
# 2147437  FY25_Engagement List_Power BI_Pivot Wk52        Y   JUN
# 2147438  FY25_Engagement List_Power BI_Pivot Wk52        Y   JUN
# 2147439  FY25_Engagement List_Power BI_Pivot Wk52        Y   JUN
#
# [2147440 rows x 170 columns]>

# %%
test_df.shape
# Out:
# (278942, 188)

# %%
train_df_fy25.shape
# Out:
# (2147440, 170)

# %%
train_df_fy25.head()
# Out:
#    Year Engagement ID      Eng ID   MS Location  \
# 0  FY25    E-67195917  67195917.0  NaN      NaN
# 1  FY25    E-67407732  67407732.0  NaN      NaN
# 2  FY25    E-45286932  45286932.0  NaN      NaN
# 3  FY25    E-45146567  45146567.0  NaN      NaN
# 4  FY25    E-42655917  42655917.0  NaN      NaN
#
#                              Engagement         Release Date  \
# 0  AB173-Signify Stat Audit YE Dec 2022  2023-02-23 00:00:00
# 1          CB104 AWSBPL Stat Audit FY23  2023-05-03 00:00:00
# 2        SC TIC Mfg+Ind Group Report 22  2023-01-04 00:00:00
# 3        SBL Certification Service 2021  2023-01-04 00:00:00
# 4                  CB171-Project Marine  2023-01-04 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-09-15 00:00:00    2024-07-07 00:00:00        2024-07-01 00:00:00
# 1      2024-02-21 00:00:00    2024-04-23 00:00:00        2024-07-04 00:00:00
# 2      2022-08-23 00:00:00    2022-10-21 00:00:00        2023-12-06 00:00:00
# 3      2022-04-19 00:00:00    2022-12-02 00:00:00                        NaN
# 4      2023-09-19 00:00:00                    NaN        2023-04-24 00:00:00
#
#    ... Location Partner                                       source_file  \
# 0  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 1  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 2  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 3  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
# 4  ...              NaN  FY25__FY25__01.Jul__Wk 02__Engagement List_Wk 02
#
#    Year1 Sub_Folder_1 Sub_Folder_2 Month_Serialized  Week  \
# 0   FY25         FY25         FY25            01JUL     2
# 1   FY25         FY25         FY25            01JUL     2
# 2   FY25         FY25         FY25            01JUL     2
# 3   FY25         FY25         FY25            01JUL     2
# 4   FY25         FY25         FY25            01JUL     2
#
#                File_Name Same FY? Month
# 0  Engagement List_Wk 02        Y   JUL
# 1  Engagement List_Wk 02        Y   JUL
# 2  Engagement List_Wk 02        Y   JUL
# 3  Engagement List_Wk 02        Y   JUL
# 4  Engagement List_Wk 02        Y   JUL
#
# [5 rows x 170 columns]

# %%
test_df.head()
# Out:
#    Year Engagement ID      Eng ID        MS    Location  \
# 0  FY26    E-67313430  67313430.0  National  Bangladesh
# 1  FY26    E-45403927  45403927.0  National  Bangladesh
# 2  FY26    E-68182933  68182933.0  National  Bangladesh
# 3  FY26    E-68506663  68506663.0  National  Bangladesh
# 4  FY26    E-45003752  45003752.0  National  Bangladesh
#
#                              Engagement         Release Date  \
# 0  CB171 - BD Lease Accelerator Support  2023-04-03 00:00:00
# 1        SEBL Stat Audit YE 30 Sep 2022  2023-01-04 00:00:00
# 2         CB178-Siemens Healthcare Ltd.  2024-04-02 00:00:00
# 3      CB138-SCCBD Stat Audit 31 Dec 24  2024-08-05 00:00:00
# 4                JBL Stat Audit FY 2021  2023-01-04 00:00:00
#
#   Last Invoice Issued Date Last Time Charged Date Last Expenses Charged Date  \
# 0      2023-07-12 00:00:00    2023-05-19 00:00:00                        NaN
# 1      2023-04-06 00:00:00    2023-06-06 00:00:00        2023-12-06 00:00:00
# 2                      NaN                    NaN                        NaN
# 3                      NaN    2025-06-02 00:00:00        2025-01-23 00:00:00
# 4      2023-03-01 00:00:00    2023-06-06 00:00:00        2023-10-17 00:00:00
#
#    ... System ANSR / Tech Revenue FYTD  \
# 0  ...                             NaN
# 1  ...                             NaN
# 2  ...                             NaN
# 3  ...                             NaN
# 4  ...                             NaN
#
#                                          source_file  Year1 Sub_Folder_1  \
# 0  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 1  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 2  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 3  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
# 4  FY26__FY26__01.Jul__Wk03__FY25_EngagementList_...   FY26         FY26
#
#   Sub_Folder_2 Month_Serialized  Week                    File_Name Same FY?  \
# 0         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 1         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 2         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 3         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
# 4         FY26            01JUL     3  FY25_EngagementList_Wk03 BI        Y
#
#   Month
# 0   JUL
# 1   JUL
# 2   JUL
# 3   JUL
# 4   JUL
#
# [5 rows x 188 columns]

# %%
# ------------------------------------------------
# 📈 Correlation Analysis — FY25 Training Data
# ------------------------------------------------

# Select only numeric columns
numeric_cols = train_df_fy25.select_dtypes(include=['number']).columns
train_numeric = train_df_fy25[numeric_cols]

# Compute correlation matrix
corr_matrix = train_numeric.corr()

display(Markdown(f"### 🔗 Correlation Matrix — FY25 Training Data ({len(numeric_cols)} numeric columns)"))
display(corr_matrix)
# Out:
# ### 🔗 Correlation Matrix — FY25 Training Data (106 numeric columns)
#                           Eng ID  Opportunity Partner ID  \
# Eng ID                  1.000000                0.041761
# Opportunity Partner ID  0.041761                1.000000
# Engagement Partner GUI  0.063314                0.818383
# Engagement Manager GUI -0.178513                0.030120
# GFIS CID               -0.517365                0.016250
# ...                          ...                     ...
# Assurance Plan         -0.204609                0.184643
# Assurance PY Actual          NaN                     NaN
# Partner MS                   NaN                     NaN
# Partner SSL                  NaN                     NaN
# Week                    0.081073               -0.002505
#
#                         Engagement Partner GUI  Engagement Manager GUI  \
# Eng ID                                0.063314               -0.178513
# Opportunity Partner ID                0.818383                0.030120
# Engagement Partner GUI                1.000000                0.039060
# Engagement Manager GUI                0.039060                1.000000
# GFIS CID                             -0.025918                0.129494
# ...                                        ...                     ...
# Assurance Plan                        0.030317               -0.065730
# Assurance PY Actual                        NaN                     NaN
# Partner MS                                 NaN                     NaN
# Partner SSL                                NaN                     NaN
# Week                                  0.000083               -0.023634
#
#                         GFIS CID  Engagement Service Code  \
# Eng ID                 -0.517365                 0.138353
# Opportunity Partner ID  0.016250                -0.008877
# Engagement Partner GUI -0.025918                 0.073364
# Engagement Manager GUI  0.129494                -0.156940
# GFIS CID                1.000000                -0.261879
# ...                          ...                      ...
# Assurance Plan               NaN                -0.043519
# Assurance PY Actual          NaN                      NaN
# Partner MS                   NaN                      NaN
# Partner SSL                  NaN                      NaN
# Week                   -0.330197                 0.019409
#
#                         Transaction Service Code  Charged Hours ETD  \
# Eng ID                                  0.138353          -0.081253
# Opportunity Partner ID                 -0.008877          -0.010453
# Engagement Partner GUI                  0.073364          -0.027183
# Engagement Manager GUI                 -0.156940           0.055074
# GFIS CID                               -0.261879           0.110698
# ...                                          ...                ...
# Assurance Plan                         -0.043519          -0.032623
# Assurance PY Actual                          NaN                NaN
# Partner MS                                   NaN                NaN
# Partner SSL                                  NaN                NaN
# Week                                    0.019409          -0.001271
#
#                         Charged Hours FYTD  Charged Hours MTD  ...  \
# Eng ID                            0.110982           0.086052  ...
# Opportunity Partner ID           -0.000650          -0.004121  ...
# Engagement Partner GUI           -0.012204          -0.012503  ...
# Engagement Manager GUI           -0.003690          -0.005791  ...
# GFIS CID                         -0.103534          -0.080394  ...
# ...                                    ...                ...  ...
# Assurance Plan                   -0.032623          -0.045564  ...
# Assurance PY Actual                    NaN                NaN  ...
# Partner MS                             NaN                NaN  ...
# Partner SSL                            NaN                NaN  ...
# Week                              0.061069          -0.007443  ...
#
#                         FYTD AR Collected  FYTD AR Collected Tax  \
# Eng ID                           0.089815               0.096185
# Opportunity Partner ID          -0.019103              -0.008030
# Engagement Partner GUI          -0.030295              -0.020875
# Engagement Manager GUI          -0.009100              -0.006275
# GFIS CID                        -0.068670              -0.077911
# ...                                   ...                    ...
# Assurance Plan                        NaN              -0.014104
# Assurance PY Actual                   NaN                    NaN
# Partner MS                            NaN                    NaN
# Partner SSL                           NaN                    NaN
# Week                             0.052056               0.054678
#
#                         FYTD Total Collections  CP AR Collected  \
# Eng ID                                0.094350         0.021140
# Opportunity Partner ID               -0.018658        -0.004914
# Engagement Partner GUI               -0.030517        -0.007740
# Engagement Manager GUI               -0.009165        -0.001917
# GFIS CID                             -0.072667        -0.016791
# ...                                        ...              ...
# Assurance Plan                        0.030303        -0.049706
# Assurance PY Actual                        NaN              NaN
# Partner MS                                 NaN              NaN
# Partner SSL                                NaN              NaN
# Week                                  0.054564        -0.005517
#
#                         CP AR Collected Tax  Assurance Plan  \
# Eng ID                             0.024111       -0.204609
# Opportunity Partner ID            -0.002535        0.184643
# Engagement Partner GUI            -0.006202        0.030317
# Engagement Manager GUI            -0.001288       -0.065730
# GFIS CID                          -0.020284             NaN
# ...                                     ...             ...
# Assurance Plan                    -0.060856        1.000000
# Assurance PY Actual                     NaN        0.997376
# Partner MS                              NaN             NaN
# Partner SSL                             NaN             NaN
# Week                              -0.007279       -0.010202
#
#                         Assurance PY Actual  Partner MS  Partner SSL      Week
# Eng ID                                  NaN         NaN          NaN  0.081073
# Opportunity Partner ID                  NaN         NaN          NaN -0.002505
# Engagement Partner GUI                  NaN         NaN          NaN  0.000083
# Engagement Manager GUI                  NaN         NaN          NaN -0.023634
# GFIS CID                                NaN         NaN          NaN -0.330197
# ...                                     ...         ...          ...       ...
# Assurance Plan                     0.997376         NaN          NaN -0.010202
# Assurance PY Actual                1.000000         NaN          NaN -0.028913
# Partner MS                              NaN         NaN          NaN       NaN
# Partner SSL                             NaN         NaN          NaN       NaN
# Week                              -0.028913         NaN          NaN  1.000000
#
# [106 rows x 106 columns]

# %%
test_df.shape
